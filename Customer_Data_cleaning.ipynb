# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
raw_data = pd.read_csv('Customer_Data.csv')

# %%
raw_data.head()
# Out:
#    customer_id  age  gender       country  monthly_visits  amount_spent  \
# 0            1   51    Male  South Africa               6         17.29
# 1            2   64    Male            UK               5         22.02
# 2            3   41  Female         Kenya               3         30.64
# 3            4   27    Male  South Africa               2         56.95
# 4            5   55  Female         Kenya               7         30.75
#
#    joined_year
# 0         2016
# 1         2016
# 2         2018
# 3         2020
# 4         2016

# %%
# Check for missing values
raw_data.isnull().sum()
# Out:
# customer_id       0
# age               0
# gender            0
# country           0
# monthly_visits    0
# amount_spent      0
# joined_year       0
# dtype: int64

# %%
# Check for duplicates
raw_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
raw_data = raw_data.drop_duplicates()

# %%
# Check if Country columns have consistent spellings
raw_data['country'].unique()
# Out:
# array(['South Africa', 'UK', 'Kenya', 'USA', 'Nigeria', 'Ghana'],
#       dtype=object)

# %%
# Check if Gender have consistent spellings
raw_data['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
# Covert Year Joined to datetime format
raw_data['joined_date'] = pd.to_datetime(raw_data['joined_year'].astype(str) + '-01-01')

# %%
# Calculate number of years as customer
raw_data['years_as_customer'] = 2025 - raw_data['joined_year']

# %%
raw_data
# Out:
#       customer_id  age  gender       country  monthly_visits  amount_spent  \
# 0               1   51    Male  South Africa               6         17.29
# 1               2   64    Male            UK               5         22.02
# 2               3   41  Female         Kenya               3         30.64
# 3               4   27    Male  South Africa               2         56.95
# 4               5   55  Female         Kenya               7         30.75
# ...           ...  ...     ...           ...             ...           ...
# 4995         4996   62   Other            UK               6         39.91
# 4996         4997   34   Other           USA               7        113.14
# 4997         4998   41   Other            UK               2        171.06
# 4998         4999   34    Male         Ghana               6         31.84
# 4999         5000   56   Other  South Africa               3         12.59
#
#       joined_year joined_date  years_as_customer
# 0            2016  2016-01-01                  9
# 1            2016  2016-01-01                  9
# 2            2018  2018-01-01                  7
# 3            2020  2020-01-01                  5
# 4            2016  2016-01-01                  9
# ...           ...         ...                ...
# 4995         2024  2024-01-01                  1
# 4996         2016  2016-01-01                  9
# 4997         2024  2024-01-01                  1
# 4998         2016  2016-01-01                  9
# 4999         2016  2016-01-01                  9
#
# [5000 rows x 9 columns]
